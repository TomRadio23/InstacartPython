# %% [markdown]
# #01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02. Importing Data

# %%
# Import the pandas, NumPy, and os libraries
df = pd.read_csv(r'/Users/thomasradio/Documents/Jupyter/230621 Tom Radio Achievement 4 Project/02 Data/Original Data/order_products__prior.csv', index_col = False)

# %%
# Turn project folder path into a string
path = r'/Users/thomasradio/Documents/Jupyter/230621 Tom Radio Achievement 4 Project'

# %%
# Check path
path
# Out:
# '/Users/thomasradio/Documents/Jupyter/230621 Tom Radio Achievement 4 Project'

# %%
# Import the “order_products__prior.csv” data set into notebook using the os library
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
# Import the “orders_checked.csv” data set into notebook using the os library
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  user_order_number  orders_day_of_week  \
# 0                 0   2539329        1                  1                   2
# 1                 1   2398795        1                  2                   3
# 2                 2    473747        1                  3                   3
# 3                 3   2254736        1                  4                   4
# 4                 4    431534        1                  5                   4
# ...             ...       ...      ...                ...                 ...
# 3421078     3421078   2266710   206209                 10                   5
# 3421079     3421079   1854736   206209                 11                   4
# 3421080     3421080    626363   206209                 12                   1
# 3421081     3421081   2977660   206209                 13                   1
# 3421082     3421082    272231   206209                 14                   6
#
# ...

# %%
# Drop "Unnamed: 0"
df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
df_ords
# Out:
#          order_id  user_id  user_order_number  orders_day_of_week  \
# 0         2539329        1                  1                   2
# 1         2398795        1                  2                   3
# 2          473747        1                  3                   3
# 3         2254736        1                  4                   4
# 4          431534        1                  5                   4
# ...           ...      ...                ...                 ...
# 3421078   2266710   206209                 10                   5
# 3421079   1854736   206209                 11                   4
# 3421080    626363   206209                 12                   1
# 3421081   2977660   206209                 13                   1
# 3421082    272231   206209                 14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
# Merge df_ords and df_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  user_order_number  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
# Check merged value counts
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # SAVE AND CHECKPOINT

# %% [markdown]
# # START TASK 4.6

# %% [markdown]
# ## 2. Export the merged file in pickle format as “orders_products_combined.pkl”.

# %%
# Look for missing values in each column
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64
